# %% [markdown]
# 先读一下 json

# %%
import json
with open("intro.json","r",encoding="utf-8") as f:
    json_data = json.load(f)
username = json_data['username']
password = json_data['password']
webdriver_path = json_data['chrome_driver_location']
useremail = json_data['useremail']
data_store_location = json_data['data_store_location']
result_analyse_location = json_data['result_analyse_location']
result_picture = json_data['result_picture']
keyword = json_data['keyword']
keyword
# Out:
# '中国 人权'

# %%
import pandas as pd
f = pd.read_csv("results/allRightRandom.csv")
f
# Out:
#       Unnamed: 0             博主昵称  \
# 0           1534      viyalkicpcc
# 1           2220         先利xianli
# 2           7091            泣泣再不见
# 3            530          想做一只锦鲤兔
# 4           4005           gzzsdd
# ...          ...              ...
# 8467         848         Danny妈妈呀
# 8468        2720         马关ty1895
# 8469        1144  每天都在努力变好的诗语Shaw
# 8470        4340             东隅有木
# 8471        6905             海客新闻
#
#                                                    微博内容               发布时间
# 0     祖国反黑站剪刀石头布RockPaperScissortrump说中国人好日子过得太久了简直垃...  2020年07月20日 23:12
# 1     始皇T侯虹斌1天赋人权凭什么女性要极其优秀才有人权而男性天生就有这些权利全中国只有屠呦呦才配...  2020年10月13日 23:23
# 2     太原市卫健委宫殿元主任请站出来承担起自己的责任还公平于百姓法律对太原市卫健委宫殿元滥用职权的...       04月15日 00:30
# 3     如果国外没有大爆发可能他们还是觉得中国人不可理喻武汉人不可理喻失去了人权当时全世界都在骂武汉...  2020年03月13日 23:48
# 4     另一方面却声称中国打算重塑世界以服务于自己的利益这往往是以牺牲美国人珍视的价值观如尊重经济公...       03月17日 23:47
# ...                                                 ...                ...
# 8467  她的文还作用呢不能上去就把人灭了的架势音乐人杨海潮挟洋自重的人怎么可能有好下场什么时候动怎么...  2020年04月19日 23:51
# 8468  海外看中国世界为什么需要中国美国小哥这场演讲火了流量收益与肤浅的实事求是而已未来属于执政党领...  2020年11月28日 22:27
# 8469  建议禁止单身女性冷冻卵子虽然我这辈子都不会去冻卵但我仍然想喷人一个女人自己都不尊重自己身为女...  2020年05月25日 23:51
# 8470  但愿伊朗能挺得住不要学了越南被山姆打了很多年中国救助了许多年最后跟仇人跑了跟恩人却像仇人一样...       04月04日 11:10
# 8471  美脱口秀演员抖包袱式讽刺美国美脱口秀演员抖包袱式批中国却惊讶发现怎么说的都是美国当地时间4月...       04月15日 15:37
#
# [8472 rows x 4 columns]

# %%
import pandas as pd
f = pd.read_csv("results/nuclear.csv")
f
# Out:
#        Unnamed: 0          博主昵称  \
# 0               0   Nos6me32132
# 1               1       潇潇暮雨的夏天
# 2               2           辉嗬嗬
# 3               3   Dr_Brittany
# 4               4  用户7582634678
# ...           ...           ...
# 10411       10411          露珠9号
# 10412       10412       孤狼复盘丨推股
# 10413       10413          前浪涛声
# 10414       10414   指标公式选股之短线出击
# 10415       10415   新余学院青年志愿者协会
#
#                                                     微博内容          发布时间
# 3     2020年03月13日 23:48
# 4          03月17日 23:47
# ...                 ...
# 8467  2020年04月19日 23:51
# 8468  2020年11月28日 22:27
# 8469  2020年05月25日 23:51
# 8470       04月04日 11:10
# 8471       04月15日 15:37
#
# [8472 rows x 3 columns]

# %%
import pandas as pd

data = pd.read_csv("results/random-right/emotion_label.csv")
data.head(100)

# data['emotion_score'].to_frame().describe()
# Out:
#     Unnamed: 0  Unnamed: 0.1          博主昵称  \
# 0            0          1534   viyalkicpcc
# 1            1          2220      先利xianli
# 2            2          7091         泣泣再不见
# 3            3           530       想做一只锦鲤兔
# 4            4          4005        gzzsdd
# ..         ...           ...           ...
# 95          95          5700         馮曉魚同學
# 96          96          6067      全民gossip
# 97          97          1405  用户5715045653
# 98          98          7199       白龙江林区检察
# 99          99           144     小女人小草_958
#
#                                                  微博内容               发布时间  \
# 0   祖国反黑站剪刀石头布RockPaperScissortrump说中国人好日子过得太久了简直垃...  2020年07月20日 23:12
# 1   始皇T侯虹斌1天赋人权凭什么女性要极其优秀才有人权而男性天生就有这些权利全中国只有屠呦呦才配...  2020年10月13日 23:23
# 2   太原市卫健委宫殿元主任请站出来承担起自己的责任还公平于百姓法律对太原市卫健委宫殿元滥用职权的...       04月15日 00:30
# 3   如果国外没有大爆发可能他们还是觉得中国人不可理喻武汉人不可理喻失去了人权当时全世界都在骂武汉...  2020年03月13日 23:48
# 4   另一方面却声称中国打算重塑世界以服务于自己的利益这往往是以牺牲美国人珍视的价值观如尊重经济公...       03月17日 23:47
# ..                                                ...                ...
# 95  微博随时随地发现新鲜事微博带你欣赏世界上每一个精彩瞬间了解每一个幕后故事分享你想表达的让全世...       04月11日 22:49
# 96  HW前HR这个是中国传统发声渠道还要加强强哥论势联合国人权理事会110多个国家批评丑国人权说...       04月12日 12:59
# 97  美国以为自己是谁是这个世界的上帝吗中国的一国两制需要它来定义并且首肯吗香港这一仗就是要让华盛...  2020年07月02日 23:38
# 98  BBC采访翻车BBC又翻车采访气候问题却问中国人权美国学者教训主持人你提问太奇怪美国怎么总攻...       04月16日 20:38
# 99        村霸把我的地上果树用土埋了美国驻华大使馆日本国驻华大使馆中国人权网北方新报超话社区精选  2020年01月30日 23:59
#
#     emotion_score
# 0        0.998112
# 1        0.999997
# 2        1.000000
# 3        1.000000
# 4        1.000000
# ..            ...
# 95       1.000000
# 96       0.997977
# 97       1.000000
# 98       1.000000
# 99       0.985119
#
# [100 rows x 6 columns]

# %%
data.loc[(data['emotion_score'] == 0)]['微博内容']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-873d9dfa50e1> in <module>
# ----> 1 data.loc[(data['emotion_score'] == 0)]['微博内容'][0]
#
# F:\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# F:\Anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# F:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 0
